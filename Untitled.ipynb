# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
from IPython.display import Image
Image(filename='guide.jpg')

# %%
file_path = 'C:/Users/hothi/CTP MTA project/A train Analysis/MTA_Subway_Terminal_On-Time_Performance__2015-2019_20231020.csv'
df = pd.read_csv(file_path)
df
# Out:
#         month        line    division  day_type  num_on_time_trips  \
# 0     2015-01           1  A DIVISION         1               6874
# 1     2015-01           2  A DIVISION         1               2920
# 2     2015-01           3  A DIVISION         1               4004
# 3     2015-01           4  A DIVISION         1               3692
# 4     2015-01           5  A DIVISION         1               3203
# ...       ...         ...         ...       ...                ...
# 1660  2019-12      S Fkln  B DIVISION         2               2072
# 1661  2019-12      S Rock  B DIVISION         1               3379
# 1662  2019-12      S Rock  B DIVISION         2               1497
# 1663  2019-12  Systemwide  Systemwide         1             137946
# 1664  2019-12  Systemwide  Systemwide         2              47175
#
#       num_sched_trips  terminal_on_time_performance
# 0                9017                      0.762338
# 1                6175                      0.472874
# ...

# %%
df['date'] = pd.to_datetime(df['month'], format='%Y-%m')
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df
# Out:
#       month        line    division  day_type  num_on_time_trips  \
# 0         1           1  A DIVISION         1               6874
# 1         1           2  A DIVISION         1               2920
# 2         1           3  A DIVISION         1               4004
# 3         1           4  A DIVISION         1               3692
# 4         1           5  A DIVISION         1               3203
# ...     ...         ...         ...       ...                ...
# 1660     12      S Fkln  B DIVISION         2               2072
# 1661     12      S Rock  B DIVISION         1               3379
# 1662     12      S Rock  B DIVISION         2               1497
# 1663     12  Systemwide  Systemwide         1             137946
# 1664     12  Systemwide  Systemwide         2              47175
#
#       num_sched_trips  terminal_on_time_performance       date  year
# 0                9017                      0.762338 2015-01-01  2015
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# month                           0
# line                            0
# division                        0
# day_type                        0
# num_on_time_trips               0
# num_sched_trips                 0
# terminal_on_time_performance    0
# date                            0
# year                            0
# dtype: int64

# %%
df = df[df['line'] == 'A']
df
# Out:
#       month line    division  day_type  num_on_time_trips  num_sched_trips  \
# 8         1    A  B DIVISION         1               4956             7327
# 32        2    A  B DIVISION         1               4390             6970
# 56        3    A  B DIVISION         1               5271             8040
# 80        4    A  B DIVISION         1               5750             8070
# 104       5    A  B DIVISION         1               4963             7369
# ...     ...  ...         ...       ...                ...              ...
# 1541     10    A  B DIVISION         2               1965             2324
# 1587     11    A  B DIVISION         1               5001             7495
# 1588     11    A  B DIVISION         2               2301             2811
# 1634     12    A  B DIVISION         1               5223             7984
# 1635     12    A  B DIVISION         2               2995             3690
#
#       terminal_on_time_performance       date  year
# ...

# %%
OnTime = df.groupby(['day_type'])['terminal_on_time_performance'].mean()
OnTime = OnTime[~OnTime.index.isin(['Systemwide'])]
OnTime = OnTime.sort_values(ascending=False)
OnTime
# Out:
# day_type
# 2    0.818396
# 1    0.605656
# Name: terminal_on_time_performance, dtype: float64

# %%
OnTime = df.groupby(['year'])['terminal_on_time_performance'].mean()
OnTime = OnTime[~OnTime.index.isin(['Systemwide'])]
OnTime = OnTime.sort_values(ascending=False)
OnTime
# Out:
# year
# 2019    0.724731
# 2015    0.663625
# 2016    0.624162
# 2017    0.549521
# 2018    0.536486
# Name: terminal_on_time_performance, dtype: float64

# %%
plt.figure(figsize=(12, 8))

plt.ylim(0, 1)
plt.gca().set_yticklabels(['{:.0%}'.format(x) for x in plt.gca().get_yticks()])
plt.xlabel('Year')
plt.ylabel('On-time Performance')
plt.title('A-Train On-time Performance from 2015-2019')
plt.xticks(df['year'].unique())
df_values = {
    2015: 0.663625,
    2016: 0.624162,
    2017: 0.549521,
    2018: 0.536486,
    2019: 0.724731
}

plt.plot(df_values.keys(), df_values.values(), color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=12)

plt.show()
# Out:
# C:\Users\hothi\AppData\Local\Temp\ipykernel_303480\944195751.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0%}'.format(x) for x in plt.gca().get_yticks()])

# %%
plt.figure(figsize=(12, 8))
#plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
plt.xlabel('Year')
plt.ylabel('On-time Performance')
plt.title('A-Train On-time Performance from 2015-2019')
plt.xticks(df['year'].unique())
df.groupby(['year'])['terminal_on_time_performance'].mean().plot(kind='line', color='red', marker='o', linestyle='dashed', linewidth=2, markersize=12)
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.title('A train Heatmap for On-Time Performance from 2015-2019')
sns.heatmap(df.corr(), annot=True, cmap='PiYG', vmin=-1, vmax=1, linewidths=0.2, annot_kws={'size': 12}, fmt='.2f')
plt.show()
# Out:
# C:\Users\hothi\AppData\Local\Temp\ipykernel_228388\4232563740.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='PiYG', vmin=-1, vmax=1, linewidths=0.2, annot_kws={'size': 12}, fmt='.2f')
