# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv('../data/MTA_Subway_Terminal_On-Time_Performance__2015-2019.csv')
df
# Out:
#         month        line    division  day_type  num_on_time_trips  \
# 0     2015-01           1  A DIVISION         1               6874
# 1     2015-01           2  A DIVISION         1               2920
# 2     2015-01           3  A DIVISION         1               4004
# 3     2015-01           4  A DIVISION         1               3692
# 4     2015-01           5  A DIVISION         1               3203
# ...       ...         ...         ...       ...                ...
# 1660  2019-12      S Fkln  B DIVISION         2               2072
# 1661  2019-12      S Rock  B DIVISION         1               3379
# 1662  2019-12      S Rock  B DIVISION         2               1497
# 1663  2019-12  Systemwide  Systemwide         1             137946
# 1664  2019-12  Systemwide  Systemwide         2              47175
#
#       num_sched_trips  terminal_on_time_performance
# 0                9017                      0.762338
# 1                6175                      0.472874
# 2                5834                      0.686322
# 3                7623                      0.484324
# 4                6491                      0.493452
# ...               ...                           ...
# 1660             2092                      0.990440
# 1661             3528                      0.957766
# 1662             1544                      0.969560
# 1663           172004                      0.801993
# 1664            54628                      0.863568
#
# [1665 rows x 7 columns]

# %%
df['date'] = pd.to_datetime(df['month'], format='%Y-%m')
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['season'] = df['date'].dt.quarter

df
# Out:
#       month        line    division  day_type  num_on_time_trips  \
# 0         1           1  A DIVISION         1               6874
# 1         1           2  A DIVISION         1               2920
# 2         1           3  A DIVISION         1               4004
# 3         1           4  A DIVISION         1               3692
# 4         1           5  A DIVISION         1               3203
# ...     ...         ...         ...       ...                ...
# 1660     12      S Fkln  B DIVISION         2               2072
# 1661     12      S Rock  B DIVISION         1               3379
# 1662     12      S Rock  B DIVISION         2               1497
# 1663     12  Systemwide  Systemwide         1             137946
# 1664     12  Systemwide  Systemwide         2              47175
#
#       num_sched_trips  terminal_on_time_performance       date  year  season
# 0                9017                      0.762338 2015-01-01  2015       1
# 1                6175                      0.472874 2015-01-01  2015       1
# 2                5834                      0.686322 2015-01-01  2015       1
# 3                7623                      0.484324 2015-01-01  2015       1
# 4                6491                      0.493452 2015-01-01  2015       1
# ...               ...                           ...        ...   ...     ...
# 1660             2092                      0.990440 2019-12-01  2019       4
# 1661             3528                      0.957766 2019-12-01  2019       4
# 1662             1544                      0.969560 2019-12-01  2019       4
# 1663           172004                      0.801993 2019-12-01  2019       4
# 1664            54628                      0.863568 2019-12-01  2019       4
#
# [1665 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# month                           0
# line                            0
# division                        0
# day_type                        0
# num_on_time_trips               0
# num_sched_trips                 0
# terminal_on_time_performance    0
# date                            0
# year                            0
# season                          0
# dtype: int64

# %%
df_b_div = df[df['line'] == 'B DIVISION']
df_b
# Out:
#       month    line    division  day_type  num_on_time_trips  num_sched_trips  \
# 8         1       A  B DIVISION         1               4956             7327
# 9         1       B  B DIVISION         1               3164             4120
# 10        1       C  B DIVISION         1               3359             4000
# 11        1       D  B DIVISION         1               4022             5288
# 12        1       E  B DIVISION         1               5453             7894
# ...     ...     ...         ...       ...                ...              ...
# 1658     12       R  B DIVISION         2               1847             2160
# 1659     12  S Fkln  B DIVISION         1               4944             4956
# 1660     12  S Fkln  B DIVISION         2               2072             2092
# 1661     12  S Rock  B DIVISION         1               3379             3528
# 1662     12  S Rock  B DIVISION         2               1497             1544
#
#       terminal_on_time_performance       date  year  season
# 8                         0.676402 2015-01-01  2015       1
# 9                         0.767961 2015-01-01  2015       1
# 10                        0.839750 2015-01-01  2015       1
# 11                        0.760590 2015-01-01  2015       1
# 12                        0.690778 2015-01-01  2015       1
# ...                            ...        ...   ...     ...
# 1658                      0.855093 2019-12-01  2019       4
# 1659                      0.997579 2019-12-01  2019       4
# 1660                      0.990440 2019-12-01  2019       4
# 1661                      0.957766 2019-12-01  2019       4
# 1662                      0.969560 2019-12-01  2019       4
#
# [1044 rows x 10 columns]

# %%
df_b_avg_year = df_b.groupby(['year'])['terminal_on_time_performance'].mean()
df_b_avg_year
# Out:
# year
# 2015    0.742580
# 2016    0.718011
# 2017    0.675054
# 2018    0.660360
# 2019    0.806203
# Name: terminal_on_time_performance, dtype: float64

# %%
df_b_avg = df_b.groupby(['year', 'month'])['terminal_on_time_performance'].mean()
df_b_avg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/khaled/Desktop/MTA_DS_Project/data-dashboard/jupyter-notebook/B-train-analysis.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/khaled/Desktop/MTA_DS_Project/data-dashboard/jupyter-notebook/B-train-analysis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df_b_avg = df_b.groupby(['year', 'month'])['terminal_on_time_performance'].mean()
#       <a href='vscode-notebook-cell:/Users/khaled/Desktop/MTA_DS_Project/data-dashboard/jupyter-notebook/B-train-analysis.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df_b_avg.head()
#
# NameError: name 'df_b' is not defined

# %%
# Create a line chart showing the monthly on-time performance percentage of the 3 train line from 2015 to 2019.
plt.figure(figsize=(20,10))
ax = sns.lineplot(x='date', y=df_b['terminal_on_time_performance']*100, data=df_b)

plt.title('Monthly On-Time Performance Percentage of the L Train Line from 2015 to 2019')
plt.xlabel('Date')
plt.ylabel('On-Time Performance Percentage (%)')
plt.xticks(rotation=45)
plt.ylim(30, 100)
plt.show()
